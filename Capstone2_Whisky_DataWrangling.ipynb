# %%
#Import pandas, matplotlib.pyplot, and seaborn in the correct lines below
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import pandas_profiling
from pandas_profiling.utils.cache import cache_file

from library.sb_utils import save_file

# %%
# CSV data file is the raw_data directory
whisky_data_init = pd.read_csv('../raw_data/scotch_review.csv')

# %%
display(whisky_data_init.shape)
# Out:
# (2247, 7)

# %%
#Call the info method on whisky data to see a summary of the data
whisky_data_init.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2247 entries, 0 to 2246
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    2247 non-null   int64
#  1   name          2247 non-null   object
#  2   category      2247 non-null   object
#  3   review.point  2247 non-null   int64
#  4   price         2247 non-null   object
#  5   currency      2247 non-null   object
#  6   description   2247 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 123.0+ KB

# %%
#Check for Null values
#Count (using `.sum()`) the number of missing values (`.isnull()`) in each column of 
#whisky_data as well as the percentages (using `.mean()` instead of `.sum()`).
#Order them (increasing or decreasing) using sort_values
#Call `pd.concat` to present these in a single table (DataFrame) with the helpful column names 'count' and '%'
missing = pd.concat([whisky_data_init.isnull().sum(), 100 * round((whisky_data_init.isnull().mean()),3)], axis=1)
missing.columns=['Count', '%']
missing.sort_values(by='Count', ascending = False)
# Out:
#               Count    %
# Unnamed: 0        0  0.0
# name              0  0.0
# category          0  0.0
# review.point      0  0.0
# price             0  0.0
# currency          0  0.0
# description       0  0.0

# %%
#Call the head method on whisky data to print the first several rows of the data
whisky_data_init.head()
# Out:
#    Unnamed: 0                                             name  \
# 0           1                   Johnnie Walker Blue Label, 40%
# 1           2  Black Bowmore, 1964 vintage, 42 year old, 40.5%
# 2           3      Bowmore 46 year old (distilled 1964), 42.9%
# 3           4                   Compass Box The General, 53.4%
# 4           5                          Chivas Regal Ultis, 40%
#
#                      category  review.point     price currency  \
# 0       Blended Scotch Whisky            97       225        $
# 1          Single Malt Scotch            97   4500.00        $
# 2          Single Malt Scotch            97  13500.00        $
# 3  Blended Malt Scotch Whisky            96       325        $
# 4  Blended Malt Scotch Whisky            96       160        $
#
#                                          description
# 0  Magnificently powerful and intense. Caramels, ...
# 1  What impresses me most is how this whisky evol...
# 2  There have been some legendary Bowmores from t...
# 3  With a name inspired by a 1926 Buster Keaton m...
# 4  Captivating, enticing, and wonderfully charmin...

# %%
# Check if multiple currencies
whisky_data_init.currency.unique()
# Out:
# array(['$'], dtype=object)

# %%
# Check if multiple categories
whisky_data_init.category.unique()
# Out:
# array(['Blended Scotch Whisky', 'Single Malt Scotch',
#        'Blended Malt Scotch Whisky', 'Grain Scotch Whisky',
#        'Single Grain Whisky'], dtype=object)

# %%
# Check and drop redundant columns
for col in whisky_data_init.columns:
    if len(whisky_data_init[col].unique()) < 3:
            display(whisky_data_init[col].unique())
whisky_data_init.drop(columns=['Unnamed: 0', 'currency'], inplace=True)
# Out:
# array(['$'], dtype=object)

# %%
# Find and replace comma separators in price column
whisky_data_init['price']=whisky_data_init['price'].str.replace(',','')

# %%
# Find all the rows wher the 'price' column contains alphabetical characters
pattern = r'[A-Za-z]'
whisky_data_init[whisky_data_init['price'].str.contains(pattern)]['price']
# Out:
# 19      $15000 or $60000/set
# 95                 60000/set
# 410                60000/set
# 576                 44/liter
# 1000               60000/set
# 1215               60000/set
# Name: price, dtype: object

# %%
# Default bottle size is 750ml. Normalize prices to 750ml bottles.
# Only 6 exceptions with inconsistent format. 
# Adjust individually, not the most elegant but in this case the most effective way.

# %%
whisky_data_init.iloc[19, 3] = 15000
whisky_data_init.iloc[95, 3] = 15000
whisky_data_init.iloc[410, 3] = 15000
whisky_data_init.iloc[576, 3] = 44*0.75
whisky_data_init.iloc[1000, 3] = 15000
whisky_data_init.iloc[1215, 3] = 15000

# %%
# Convert price to float
whisky_data_init['price'] = whisky_data_init['price'].astype('float')

# %%
# Rename columns to reflect normalization and simplification  
whisky_data_init.rename(columns={"review.point": "points","price": "price ($/750ml)"},inplace=True)

# %%
# Review Data after intial cleaning
whisky_data_init.info()
whisky_data_init.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2247 entries, 0 to 2246
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             2247 non-null   object
#  1   category         2247 non-null   object
#  2   points           2247 non-null   int64
#  3   price ($/750ml)  2247 non-null   float64
#  4   description      2247 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 87.9+ KB
#                                               name  \
# 0                   Johnnie Walker Blue Label, 40%
# 1  Black Bowmore, 1964 vintage, 42 year old, 40.5%
# 2      Bowmore 46 year old (distilled 1964), 42.9%
# 3                   Compass Box The General, 53.4%
# 4                          Chivas Regal Ultis, 40%
#
#                      category  points  price ($/750ml)  \
# 0       Blended Scotch Whisky      97            225.0
# 1          Single Malt Scotch      97           4500.0
# 2          Single Malt Scotch      97          13500.0
# 3  Blended Malt Scotch Whisky      96            325.0
# 4  Blended Malt Scotch Whisky      96            160.0
#
#                                          description
# 0  Magnificently powerful and intense. Caramels, ...
# 1  What impresses me most is how this whisky evol...
# 2  There have been some legendary Bowmores from t...
# 3  With a name inspired by a 1926 Buster Keaton m...
# 4  Captivating, enticing, and wonderfully charmin...

# %%
# Check and count duplicate names
whisky_data_init.duplicated('name').sum()
# Out:
# 24

# %%
# List duplicate names
whisky_data_init[whisky_data_init.duplicated(subset=['name'], keep=False)].sort_values('name')
# Out:
#                                                    name  \
# 983                           Aberlour 12 year old, 40%
# 1613                          Aberlour 12 year old, 40%
# 180                           Aberlour 18 year old, 43%
# 286                           Aberlour 18 year old, 43%
# 594                              Arran 18 year old, 46%
# 593                              Arran 18 year old, 46%
# 1442                         Benromach 15 year old, 43%
# 1009                         Benromach 15 year old, 43%
# 303                           Bowmore, 18 year old, 43%
# 352                           Bowmore, 18 year old, 43%
# 570   Chapter 7 (undisclosed Highland distillery), 5...
# 537   Chapter 7 (undisclosed Highland distillery), 5...
# 1783                         Compass Box Oak Cross, 43%
# 385                          Compass Box Oak Cross, 43%
# 38                    Compass Box The Peat Monster, 46%
# 387                   Compass Box The Peat Monster, 46%
# 2061                        Glen Moray 12 year old, 40%
# 918                         Glen Moray 12 year old, 40%
# 2146                      Glen Moray Elgin Classic, 40%
# 1142                      Glen Moray Elgin Classic, 40%
# 321                        Glen Scotia 18 year old, 46%
# 1248                       Glen Scotia 18 year old, 46%
# 662                     Glenrothes Vintage Reserve, 40%
# 1079                    Glenrothes Vintage Reserve, 40%
# 1967                        Inchmurrin 12 year old, 46%
# 2049                        Inchmurrin 12 year old, 46%
# 2120                        Inchmurrin 18 year old, 46%
# 1843                        Inchmurrin 18 year old, 46%
# 2183                        Inchmurrin 18 year old, 46%
# 488                          Laphroaig Triple Wood, 48%
# 70                           Laphroaig Triple Wood, 48%
# 2125                           Ledaig, 10 year old, 43%
# 2116                           Ledaig, 10 year old, 43%
# 491                           Longmorn 16 year old, 48%
# 682                           Longmorn 16 year old, 48%
# 681                           Longmorn 16 year old, 48%
# 231                            Longrow 18 year old, 46%
# 132                            Longrow 18 year old, 46%
# 1997          Master of Malt Reference Series II, 47.5%
# 1366          Master of Malt Reference Series II, 47.5%
# 897                        Springbank, 18 year old, 46%
# 896                        Springbank, 18 year old, 46%
# 510                         Talisker 10 year old, 45.8%
# 513                         Talisker 10 year old, 45.8%
# 1559  Wemyss Malts (distilled at Clynelish) “A Day a...
# 1557  Wemyss Malts (distilled at Clynelish) “A Day a...
#
#                         category  points  price ($/750ml)  \
# 983           Single Malt Scotch      87             55.0
# 1613          Single Malt Scotch      84             44.0
# 180           Single Malt Scotch      92            125.0
# 286           Single Malt Scotch      91            100.0
# 594           Single Malt Scotch      89            100.0
# 593           Single Malt Scotch      89            120.0
# 1442          Single Malt Scotch      85            100.0
# 1009          Single Malt Scotch      87            100.0
# 303           Single Malt Scotch      91             85.0
# 352           Single Malt Scotch      91             85.0
# 570           Single Malt Scotch      90            180.0
# 537           Single Malt Scotch      90            180.0
# 1783       Blended Scotch Whisky      83             40.0
# 385   Blended Malt Scotch Whisky      90             59.0
# 38    Blended Malt Scotch Whisky      94             60.0
# 387        Blended Scotch Whisky      90             60.0
# 2061          Single Malt Scotch      81             40.0
# 918           Single Malt Scotch      88             40.0
# 2146          Single Malt Scotch      80             56.0
# 1142          Single Malt Scotch      87             25.0
# 321           Single Malt Scotch      91            113.0
# 1248          Single Malt Scotch      86            105.0
# 662           Single Malt Scotch      89             55.0
# 1079          Single Malt Scotch      87             60.0
# 1967          Single Malt Scotch      82             52.0
# 2049          Single Malt Scotch      81             75.0
# 2120          Single Malt Scotch      80            150.0
# 1843          Single Malt Scotch      83            111.0
# 2183          Single Malt Scotch      79            108.0
# 488           Single Malt Scotch      90            100.0
# 70            Single Malt Scotch      94            100.0
# 2125          Single Malt Scotch      80             48.0
# 2116          Single Malt Scotch      80             48.0
# 491           Single Malt Scotch      90            252.0
# 682           Single Malt Scotch      89            110.0
# 681           Single Malt Scotch      89             90.0
# 231           Single Malt Scotch      92            220.0
# 132           Single Malt Scotch      93            280.0
# 1997  Blended Malt Scotch Whisky      82             91.0
# 1366       Blended Scotch Whisky      86             85.0
# 897           Single Malt Scotch      88            160.0
# 896           Single Malt Scotch      88            190.0
# 510           Single Malt Scotch      90             50.0
# 513           Single Malt Scotch      90             50.0
# 1559          Single Malt Scotch      85             95.0
# 1557          Single Malt Scotch      85            105.0
#
#                                             description
# 983   Matured in a mix of bourbon and sherry casks. ...
# 1613  Somehow this 12 year old—a mix of sherry and A...
# 180   This has a significant proportion of sherry wo...
# 286   There was an Aberlour 18 on the market for a s...
# 594   Following the 2015 limited edition release of ...
# 593   This expression is the culmination of Arran’s ...
# 1442  A new member of the core range, this has a cin...
# 1009  The aim with Benromach was always to rediscove...
# 303   This replaces the 17 year old in the standard ...
# 352   This replaces the 17 year old in the standard ...
# 570   Swiss-based Chapter 7 released this 19 year ol...
# 537   Swiss-based Chapter 7 released this 19 year ol...
# 1783  A blend of three different single malts. Its n...
# 385   Compared to Asyla, this has noticeable added r...
# 38    The formula for this whisky has changed slight...
# 387   A fantastically earthy whisky bristling with r...
# 2061  A malt that was overlooked by one owner (Glenm...
# 918   Matured in bourbon casks, this expression offe...
# 2146  The onionskin hue gives the initial indication...
# 1142  This offers an enticing nose of honey, malt, a...
# 321   New for 2017, this was matured for 17 years in...
# 1248  Lemons, salt, and then malt on the nose. The p...
# 662   Glenrothes is always this fascinating mix of t...
# 1079  A new NAS, this has a thick, silky nose in cla...
# 1967  Matured in a mixture of bourbon, refill, and r...
# 2049  Soft and warm on the nose, with peaches in syr...
# 2120  Rich on the nose, with damp tweed, malt, and a...
# 1843  The nose offers less rich, peachy fruit than t...
# 2183  Inchmurrin has enjoyed a higher profile since ...
# 488   Similar to Laphroaig Quarter Cask, but also fi...
# 70    This is the first time I’ve been up for review...
# 2125  Sweet, ripe barley, balanced by damp peat, tar...
# 2116  Sweet, ripe barley, balanced by damp peat, tar...
# 491   Having replaced the 16 year old Longmorn with ...
# 682   Longmorn may be slightly better known, but it’...
# 681   Longmorn is now being bottled one year older. ...
# 231   This limited release was matured in 60% refill...
# 132   Straw/honey color. Light to medium weight, wit...
# 1997  This laudable effort of comparative whiskies e...
# 1366  Now listen up class, it’s time for your next w...
# 897   A good dose of sherry here, but there’s plenty...
# 896   Nice to see stocks distilled after the 1980s ‘...
# 510   Fresh, vibrant. Appetizingly briny, with notes...
# 513   Another that should need no introduction. The ...
# 1559  One of the latest batch of single cask bottlin...
# 1557  One of the latest single cask bottlings (354 b...

# %%
# Calculate mean review value and mean price for duplicates (could be processed differently)
whisky_data_init['rev_points'] = whisky_data_init.groupby('name')['points'].transform('mean')
whisky_data_init['rev_price ($/750ml)'] = whisky_data_init.groupby('name')['price ($/750ml)'].transform('mean')

# %%
# Drop the duplicate names (keep the first each time)
whisky_data_init.drop_duplicates(subset=['name'], keep='first', inplace=True)

# %%
# Drop the old columns
whisky_data_init.drop(columns=['price ($/750ml)', 'points'], inplace=True)

# %%
# Rename affected columns to original labels
whisky_data_init.rename(columns={'rev_price ($/750ml)': 'price ($/750ml)', 'rev_points': 'points'}, inplace=True)

# %%
# Verify no duplicates left
whisky_data_init.duplicated('name').sum()
# Out:
# 0

# %%
# Extract additional parameters (code adopted from Orfanakis Konstantinos)
# Age converted to float
whisky_data_init['age'] = whisky_data_init['name'].str.extract(r'(\d+) year')[0].astype(float)
# Remove ABV from Names
whisky_data_init['name'] = whisky_data_init['name'].str.replace(' ABV ', '')
# Alcohol %
whisky_data_init['alcohol%'] = whisky_data_init['name'].str.extract(r"([\(\,\,\'\"\’\”\$] ? ?\d+(\.\d+)?%)")[0]
whisky_data_init['alcohol%'] = whisky_data_init['alcohol%'].str.replace("[^\d\.]", "").astype(float)
# Cost per review point rounded to 2 digits
whisky_data_init['cost_per_point'] = round(whisky_data_init['price ($/750ml)']/whisky_data_init['points'],2)

# %%
# Reveiw data
whisky_data_init.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2223 entries, 0 to 2246
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             2223 non-null   object
#  1   category         2223 non-null   object
#  2   description      2223 non-null   object
#  3   points           2223 non-null   float64
#  4   price ($/750ml)  2223 non-null   float64
#  5   age              1197 non-null   float64
#  6   alcohol%         2206 non-null   float64
#  7   cost_per_point   2223 non-null   float64
# dtypes: float64(5), object(3)
# memory usage: 156.3+ KB

# %%
# Reveiw and display data for 10 random whiskies
whisky_data_init.sample(10)
# Out:
#                                                    name  \
# 1137  Kilchoman 100% Islay (distilled 2008, bottled ...
# 662                     Glenrothes Vintage Reserve, 40%
# 1058     GlenDronach Sauternes Finish, 46%, 14 year old
# 392                       Royal Salute 21 year old, 40%
# 1905  Douglas Laing Old Particular (distilled at Inv...
# 1520           Littlemill 21 year old Burns Malt, 55.1%
# 166   Compass Box, The Peat Monster, Reserve Edition...
# 129        Lagavulin 1995 Feis Ile 2014 bottling, 54.7%
# 668                                     Murray McDavid
# 364   Duncan Taylor (distilled at Royal Lochnagar) 2...
#
#                         category  \
# 1137          Single Malt Scotch
# 662           Single Malt Scotch
# 1058          Single Malt Scotch
# 392        Blended Scotch Whisky
# 1905         Single Grain Whisky
# 1520          Single Malt Scotch
# 166   Blended Malt Scotch Whisky
# 129           Single Malt Scotch
# 668           Single Malt Scotch
# 364           Single Malt Scotch
#
#                                             description  points  \
# 1137  The only Islay distillery not on the coast — a...    87.0
# 662   Glenrothes is always this fascinating mix of t...    88.0
# 1058  The rich, sweet Sauternes dessert wine adds it...    87.0
# 392   Not exactly a new whisky for the Jubilee, just...    90.0
# 1905  Sweet top notes of brioche loaf with baking sp...    83.0
# 1520  Online retailer TheWhiskyBarrel.com has releas...    85.0
# 166   Compass Box Whiskies celebrates the fifth anni...    92.0
# 129   A sherry-cask Lagavulin, this immediately show...    93.0
# 668   Yellow gold color. Fresh, floral aromas (remin...    89.0
# 364   Soft, soothing, and gentle. Layered fruit (bri...    91.0
#
#       price ($/750ml)   age  alcohol%  cost_per_point
# 1137            100.0   NaN      50.0            1.15
# 662              57.5   NaN      40.0            0.65
# 1058             75.0  14.0      46.0            0.86
# 392             170.0  21.0      40.0            1.89
# 1905            110.0  28.0      56.5            1.33
# 1520             72.0  21.0      55.1            0.85
# 166             150.0   NaN      48.9            1.63
# 129             167.0   NaN      54.7            1.80
# 668             150.0   NaN       NaN            1.69
# 364             200.0  23.0      46.3            2.20

# %%
# Save initial data set to final data_frame and verify data is identical to cleaned intial data
whisky_data_final = whisky_data_init.copy()
whisky_data_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2223 entries, 0 to 2246
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             2223 non-null   object
#  1   category         2223 non-null   object
#  2   description      2223 non-null   object
#  3   points           2223 non-null   float64
#  4   price ($/750ml)  2223 non-null   float64
#  5   age              1197 non-null   float64
#  6   alcohol%         2206 non-null   float64
#  7   cost_per_point   2223 non-null   float64
# dtypes: float64(5), object(3)
# memory usage: 156.3+ KB

# %%
# Export csv file of cleaned final data set
whisky_data_final.to_csv('whisky_data_final.csv')
